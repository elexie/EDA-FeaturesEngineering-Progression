# %%
#imports
import pandas as pd
import copy
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from sklearn.metrics import recall_score, precision_score
from sklearn.model_selection import KFold, train_test_split,cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

from sklearn import tree
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

from sklearn.metrics import accuracy_score

from sklearn import svm, tree, linear_model, neighbors, naive_bayes, ensemble, discriminant_analysis, gaussian_process

# %matplotlib inline
plt.style.use('ggplot')

# %% [markdown]
# <p>References</p>
# <table style= "width:100%;">
#   <tr>
#     <th>Company</th>
#     <th>Contact</th>
#     <th>Country</th>
#   </tr>
#   <tr>
#     <td><a style= "width:100%; text-decoration:none" href="https://www.kaggle.com/kanncaa1/data-sciencetutorial-for-beginners">Data Science Tutorial For Beginners-DATAI(kaggle.com)</a></td>
#     <td><a style= "width:100%; text-decoration:none" href="https://www.kaggle.com/yassineghouzam/titanic-top-4-with-ensemble-modeling">Titanic top 4 with Ensemble Modeling</a></td>
#     <td><a style= "width:100%; text-decoration:none" href="http://www.datasciencemadesimple.com/encode-decode-column-dataframe-python/">Encode and Decode Column</a></td>
#   </tr>
#   <tr>
#     <td><a style= "width:100%; text-decoration:none" href="https://www.kaggle.com/kanncaa1/machine-learning-tutorial-for-beginners">Machine Learning Tutorial For Beginners-DATAI(kaggle.com)</a></td>
#     <td><a style= "width:100%; text-decoration:none" href="https://mlalgorithm.wordpress.com/2016/05/28/pre-processing-feature-selection-feature-scaling-and-dimensionality-reduction/">Pre-Processing, Feature Scaling, Dimensionality  Reduction</a></td>
#     <td><a style= "width:100%; text-decoration:none" href="https://medium.com/open-machine-learning-course/open-machine-learning-course-topic-1-exploratory-data-analysis-with-pandas-de57880f1a68">Exploratorary Data Analysis with Pandas</a></td>
#   </tr>
#   <tr>
#     <td><a style= "width:100%; text-decoration:none" href="https://www.kaggle.com/kanncaa1/feature-selection-and-data-visualization">Feature Selection and Data Visualization</a></td>
#     <td><a style= "width:100%; text-decoration:none" href="https://www.kaggle.com/gzuidhof/full-preprocessing-tutorial">Full Preprocessing</a></td>
#     <td>..</td>
#   </tr>
#   <tr>
#     <td><a style= "width:100%; text-decoration:none" href="https://www.kaggle.com/ash316/eda-to-prediction-dietanic">EDA To Prediction</a></td>
#     <td>..</td>
#     <td>..</td>
#   </tr>
#   <tr>
#     <td><a style= "width:100%; text-decoration:none" href="https://www.kaggle.com/arthurtok/introduction-to-ensembling-stacking-in-python">Ensembling/Stacking</a></td>
#     <td><a href="https://www.youtube.com/watch?v=LgLcfZjNF44">Learn Kaggle techniques from Kaggle #1, Owen Zhang</a></td>
#     <td>..</td>
#   </tr>
#   <tr>
#     <td><a style= "width:100%; text-decoration:none" href="https://www.kaggle.com/jkokatjuhha/we-are-from-our-childhood/data">We are from our Childhood</a></td>
#     <td>..</td>
#     <td>..</td>
#   </tr>
# </table>

# %% [markdown]
# <h1 style = "color : blue;font-size:4em; text-align:center">2)EDA</h1>
# <ol style = "color : ;font-size:1.5em;">
# <li>Survey</li>
# <li>Clean</li>
# <li>Visualize</li>
# </ol>

# %% [markdown]
# <h1 style = "color : darkred; font-size: 3em; font-family:Verdana">SURVEY</h1>
#
# <table style="width:100%; font-size:1.2em;align:left; font-family:Courier New;">
#   <tr>
#     <th>Company</th>
#     <th>Contact</th>
#     <th>Country</th>
#   </tr>
#
#   <tr>
#     <td>..</td>
#     <td>notnull()<br>isnull()</td>
#     <td>..</td>
#   </tr>
#
#   <tr>
#     <td>columns<br>columns()<br>.columns().values.tolist()</td>
#     <td>shape<br>size()<br>empty()<br>ndim</td>
#     <td>crossTab</td>
#  </tr>
#
#   <tr>
#     <td>index.summary()</td>
#     <td>rename()</td>
#     <td>..</td>
#   </tr>
#
#   <tr>
#     <td>head()<br>tail()</td>
#     <td>tolist()</td>
#     <td>count()<br>df['colNum'].count()</td>
#   </tr>
#
#   <tr>
#     <td>apply()<br>apply_map()</td>
#     <td>df.index.has_duplicates<br>df.index.duplicated()</td>
#     <td>..</td>
#   </tr>
#
#    <tr>
#     <td>value_counts()<br>value_counts(bins = 3)</td>
#     <td>isnumeric()</td>
#     <td>..</td>
#   </tr>
#
#    <tr>
#     <td>dtype<br>df.dtypes<br>select_dtypes()<br>df.dtypes.sample(10)</td>
#     <td>..</td>
#     <td>..</td>
#   </tr>
#
#   <tr>
#     <td>loc()<br>iloc()</td>
#     <td>value_counts()</td>
#     <td>...</td>
#   </tr>
#
#   <tr>
#     <td>...</td>
#     <td>...</td>
#     <td>...</td>
#   </tr>
#
#   <tr>
#     <td>...</td>
#     <td>...</td>
#     <td>...</td>
#   </tr>
# </table>

# %%
df = pd.read_csv('~/documents/mlFiles/2016Voter/survey.csv')
display(df.shape)
display(df.columns)
display(df.index)
display(df.head(5))
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (423,564) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (8000, 668)
# Index(['case_identifier', 'weight', 'PARTY_AGENDAS_rand_2016',
#        'pp_primary16_2016', 'pp_demprim16_2016', 'pp_repprim16_2016',
#        'inputstate_2016', 'izip_2016', 'votereg2_2016', 'votereg_f_2016',
#        ...
#        'post_HouseCand3Name_2012', 'post_HouseCand3Party_2012',
#        'post_SenCand1Name_2012', 'post_SenCand1Party_2012',
#        'post_SenCand2Name_2012', 'post_SenCand2Party_2012',
#        'post_SenCand3Name_2012', 'post_SenCand3Party_2012', 'starttime_2016',
#        'endtime_2016'],
#       dtype='object', length=668)
# RangeIndex(start=0, stop=8000, step=1)
#    case_identifier    weight PARTY_AGENDAS_rand_2016  \
# 0              779  0.358213        Republican Party
# ...

# %%
df.describe()

# %%
df.index.summary()

# %%
df.dtypes.sample(10)

# %% [markdown]
# <h1 style = "color : darkred; font-size: 3em; font-family:Verdana">TRANSFORM</h1>
#
# <table style="width:100%; font-size:1.1em;align:left;font-family:Courier New;">
#   <tr>
#     <th>Null Handling</th>
#     <th>Aggregrating/Grouping</th>
#     <th>Country</th>
#   </tr>
#
#   <tr>
#     <td>read_csv()</td>
#     <td>head()</td>
#     <td>shape</td>
#   </tr>
#
#   <tr>
#     <td>indexing : reset_index(), set_index()</td>
#     <td>groupBy</td>
#     <td>crossTab</td>
#   </tr>
#
#   <tr>
#     <td>aggregate()</td>
#     <td>df.rename(columns={'oldName1': 'newName1', 'oldName2': 'newName2'})</td>
#     <td>astype()</td>
#   </tr>
#
#   <tr>
#     <td>values</td>
#     <td>df.columns = ['a', 'b']</td>
#     <td>.columns().values.tolist()</td>
#   </tr>
#
#   <tr>
#     <td>replace</td>
#     <td>df.rename(index={1: 'a'})</td>
#     <td></td>
#   </tr>
#
#   <tr>
#     <td>np.sum<br>np.mean</td>
#     <td>value_counts()</td>
#     <td>tolist</td>
#   </tr>
#
#   <tr>
#     <td>apply vs applymap vs map</td>
#     <td>fillna()</td>
#     <td>dataframe.nunique()</td>
#   </tr>
#
#   <tr>
#     <td>filter()</td>
#     <td>...</td>
#     <td>...</td>
#   </tr>
#
#     <tr>
#     <td><a href="https://www.geeksforgeeks.org/python-pandas-dataframe-isin/">isin()</a><br><span style="font-size:.7em">filter1 = data["Gender"].isin(["Female"])<br>
# filter2 = data["Team"].isin(["Engineering", "Distribution", "Finance" ])<br>
# data[filter1 & filter2]</span></td>
#     <td>...</td>
#     <td>...</td>
#   </tr>
#
#   <tr>
#     <td>dropna()<br>dropna(axis=1)</td>
#     <td>drop(axis=1)</td>
#     <td>...</td>
#   </tr>
#
#
#   <tr>
#     <td>...</td>
#     <td>...</td>
#     <td>...</td>
#   </tr>
#
#   <tr>
#     <td>...</td>
#     <td>...</td>
#     <td>...</td>
#   </tr>
#
#
#   <tr>
#     <td>...</td>
#     <td>..</td>
#     <td>...</td>
#   </tr>
#
#
#   <tr>
#     <td>...</td>
#     <td>...</td>
#     <td>...</td>
#   </tr>
#
# </table>

# %% [markdown]
# <h1 style = "color : darkred; font-size: 3em; font-family:Verdana">VISUALIZE</h1>
#
# <table style="width:100%;font-family:Courier New;font-size:1.1em;align:left;">
#   <tr>
#     <th>Plots</th>
#     <th>Contact</th>
#     <th>Country</th>
#   </tr>
#
#   <tr>
#     <td>sns.heatmap(df.corr(),annot=True...)</td>
#     <td>jointplot</td>
#     <td>barplot</td>
#   </tr>
#
#   <tr>
#     <td>violinplot</td>
#     <td>relplot</td>
#     <td>jointplot</td>
#   </tr>
#
#   <tr>
#     <td>pairplot</td>
#     <td>...</td>
#     <td>...</td>
#   </tr>
#
#   <tr>
#     <td>scatterplot</td>
#     <td>tolist</td>
#     <td>.columns().values.tolist()</td>
#   </tr>
#
#   <tr>
#     <td>replace</td>
#     <td>apply</td>
#     <td>apply_map</td>
#   </tr>
#
#   <tr>
#     <td>factorplot</td>
#     <td>relplot</td>
#     <td>kdeplot</td>
#   </tr>
#
#  <tr>
#   <td>boxplot</td>
#   <td>
#   sorted barplot<br>
#   <span style="font-size:.7em;">df.groupby(['categoricalColumn'])['numericalColumn']<br>.aggregate(np.sum)<br>.reset_index()<br>.sort_values('numericalColumn',ascending = False)</span>
#   </td>
#   <td>...</td>
#   </tr>
# </table>

# %% [markdown]
# <h1 style = "color : blue;font-size:4em; text-align:center">3)Features Engineering</h1>
# <ol style = "color : ;font-size:1.5em;">

# %% [markdown]
# <table style="width:100%; font-size:1.1em;align:left; font-family:Courier New">
#   <tr>
#     <th>Plots</th>
#     <th>Contact</th>
#     <th>Country</th>
#   </tr>
#
#   <tr>
#     <td>pd.get_dummies(df)</td>
#     <td>...</td>
#     <td>...</td>
#   </tr>
#
#   <tr>
#     <td>from sklearn.preprocessing import<span style="color:darkred"> StandardScaler</span></td>
#     <td>...</td>
#     <td>...</td>
#   </tr>
#
#   <tr>
#     <td>from sklearn.preprocessing import<span style="color:darkred"> Pipeline</span></td>
#     <td>...</td>
#     <td><b>Dimensionality Reduction</b><br>
#     <ol>
#     <li><b>[Principal Component Analysis]</b><br>from sklearn.decomposition import <span style="color:darkred">PCA<br>IncrementalPCA<br>KernelPCA</span>      </li>
#         <li><i>t-Distributed Stochastic Neighbor Embedding (t-SNE)</i><br>from sklearn.manifold import <span style="color:darkred"> TSNE</span>
# </li>
#     <li><b>[Linear Discriminant Analysis]</b><br>from sklearn.discriminant_analysis import <span style="color:darkred">LinearDiscriminantAnalysis</span></li>
#     </ol>
#     </td>
#   </tr>
#
#   <tr>
#     <td>from sklearn.manifold import <span style="color:darkred">TSNE</span></td>
#     <td>from scipy.cluster.hierarchy import <span style="color:darkred">linkage,dendrogram</span></td>
#     <td>...</td>
#   </tr>
#
#   <tr>
#     <td>qcut()</td>
#     <td>df.drop_duplicates()</td>
#     <td>...</td>
#   </tr>
#
#   <tr>
#     <td>...</td>
#     <td>...</td>
#     <td>...</td>
#   </tr>
#
#   <tr>
#     <td>...</td>
#     <td>...</td>
#     <td>...</td>
#   </tr>
#
#   <tr>
#     <td>...</td>
#     <td>...</td>
#     <td>...</td>
#   </tr>
#
#     <tr>
#     <td>...</td>
#     <td>...</td>
#     <td>...</td>
#   </tr>
#
#   <tr>
#     <td>...</td>
#     <td>...</td>
#     <td>...</td>
#   </tr>
# </table>

# %% [markdown]
# <h1 style = "color : blue;font-size:4em; text-align:center">4)Model Selection</h1>
# <table style="width:100%; font-size:1.1em;align:left; font-family:Courier New">
#   <tr>
#     <th>Plots</th>
#     <th>Contact</th>
#     <th>Country</th>
#   </tr>
#
#   <tr>
#     <td>from sklearn.linear_model import <span style="color:darkred">LogisticRegression</span></td>
#     <td>from sklearn import <span style="color:darkred">svm</span></td>
#     <td>from sklearn.ensemble import <span style="color:darkred">RandomForestClassifier GradientBoostingClassifier  VotingClassifier BaggingClassifier AdaBoostClassifier GradientBoostingRegressor</span></td>
#   </tr>
#
#   <tr>
#     <td>from sklearn.naive_bayes import <span style="color:darkred">GaussianNB</span></td>
#     <td>from sklearn.tree import <span style="color:darkred">DecisionTreeClassifier</span></td>
#     <td>from sklearn.model_selection import <span style="color:darkred">train_test_split</span></td>
#   </tr>
#
#   <tr>
#     <td>from sklearn.neighbors import <span style="color:darkred">KNeighborsClassifier</span></td>
#     <td>...</td>
#     <td>...</td>
#   </tr>
#
#   <tr>
#     <td>from xgboost import <span style="color:darkred">XGBClassifier</span></td>
#     <td>...</td>
#     <td>...</td>
#   </tr>
#
#   <tr>
#     <td>from sklearn.tree import <span style="color:darkred">DecisionTreeClassifier</span></td>
#     <td>...</td>
#     <td>...</td>
#   </tr>
#
#   <tr>
#     <td>from sklearn.cross_validation import <span style="color:darkred">StratifiedKFold</span></td>
#     <td>...</td>
#     <td>...</td>
#   </tr>
# </table>

# %% [markdown]
# <h1 style = "color : blue;font-size:4em; text-align:center">5)Model Evaluation and Hyperparemeter Tuning</h1>
# <ol style = "color : ;font-size:1.5em;">

# %% [markdown]
# <table style="width:100%; font-size:1em;align:left; font-family:Courier New;">
#   <tr>
#     <th>Plots</th>
#     <th>Contact</th>
#     <th>Country</th>
#   </tr>
#
#   <tr>
#     <td>Lasso (L1): Absolute Valued Magnitude<br> Ridge(L2) : Squared Magnitude</td>
#     <td>from sklearn.linear_model import <span style="color:darkred">Ridge</span></td>
#     <td>from sklearn import <span style="color:darkred">metrics</span></td>
#   </tr>
#
#   <tr>
#     <td>GridSearchCV</td>
#     <td>from sklearn.metrics import <span style="color:darkred">confusion_matrix</span></td>
#     <td>from sklearn.metrics import  <span style="color:darkred">roc_curve<br>mean_squared_error</span></td>
#   </tr>
#
#   <tr>
#     <td>sns.heatmap(confusion_matrix())</td>
#     <td>feature_importances()</td>
#     <td>from sklearn.linear_model import <span style="color:darkred">Lasso</span></td>
#   </tr>
#
#   <tr>
#     <td>from sklearn.model_selection import <span style="color:darkred">cross_val_score</span></td>
#     <td>.fit()</td>
#     <td>...</td>
#   </tr>
#
#   <tr>
#     <td>...</td>
#     <td>.predict()</td>
#     <td>...</td>
#   </tr>
#
#   <tr>
#     <td>Mean Squared Error<br> Root Mean Squared Error</td>
#     <td>...</td>
#     <td>...</td>
#   </tr>
# </table>
