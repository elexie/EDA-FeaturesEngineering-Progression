# %%
#imports
import pandas as pd
import copy
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from sklearn.metrics import recall_score, precision_score
from sklearn.model_selection import KFold, train_test_split,cross_val_score
from sklearn.model_selection import GridSearchCV

# %matplotlib inline
plt.style.use('ggplot')

# %%
df=pd.read_csv("../../documents/mlFiles/adult.csv")
display(df.shape)
display(df.columns)
display(df.head(5))
# Out:
# (32561, 15)
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# ...

# %%
display(df.shape)
display(df.info())
# Out:
# (32561, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education.num     32561 non-null int64
# marital.status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital.gain      32561 non-null int64
# capital.loss      32561 non-null int64
# hours.per.week    32561 non-null int64
# native.country    32561 non-null object
# income            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# None

# %% [markdown]
# <h2>Create a 4 column table that summarizes that dataset</h2>
# <p>column name, unique values, unique value counts, null count</p>
# <p>exclude the following continuous columns:</p>
# <ul>
# <li>capital.gain</li>
# <li>capital.loss</li>
# <li>hours.per.week</li>
# <li>age</li>
# <li>fnlwgt</li>
# </ul>
# <p>According to df.info() there are no null rows in the dataset but this is only<br> because the values that would otherwise be 'NaN' have been replaced with a '?' </p>

# %%
"""
make sure to name the column 'nUnique' not 'nunique' since 'nunique' is a property
of DataFrames

in this case 'nanCnt' or nanCount column returns the total count of '?'
"""
def countNaNs(col_name):
    return len(df[df[col_name].astype(object)=='?']) 
    #if numerical columns are not converted to object the comparison to '?' will not work

def makeSummaryDf(cols):
    summaryDf=pd.DataFrame(columns=['colName','unique','nUnique','nanCnt'])
    summaryDf.colName=cols
    summaryDf.unique=summaryDf.colName.apply(lambda x: df[x].unique())
    summaryDf.nUnique=summaryDf.colName.apply(lambda x: df[x].nunique())
    summaryDf.nanCnt=summaryDf.colName.apply(countNaNs)
    return summaryDf

# %%
summaryDf=makeSummaryDf(list(set(df.columns)-set(['age','fnlwgt','capital.gain','capital.loss','hours.per.week'])))

# %%
summaryDf
# Out:
#           colName                                             unique  nUnique  \
# 0  marital.status  [Widowed, Divorced, Separated, Never-married, ...        7
# 1             sex                                     [Female, Male]        2
# 2   education.num  [9, 10, 4, 6, 16, 15, 13, 14, 7, 12, 11, 2, 3,...       16
# 3      occupation  [?, Exec-managerial, Machine-op-inspct, Prof-s...       15
# 4       workclass  [?, Private, State-gov, Federal-gov, Self-emp-...        9
# 5    relationship  [Not-in-family, Unmarried, Own-child, Other-re...        6
# 6  native.country  [United-States, ?, Mexico, Greece, Vietnam, Ch...       42
# 7          income                                      [<=50K, >50K]        2
# 8            race  [White, Black, Asian-Pac-Islander, Other, Amer...        5
# 9       education  [HS-grad, Some-college, 7th-8th, 10th, Doctora...       16
#
#    nanCnt
# 0       0
# 1       0
# 2       0
# 3    1843
# 4    1836
# 5       0
# 6     583
# 7       0
# ...

# %% [markdown]
# <h2>Plotting</h2>
# <p>plot every categorical column and hue byr race, then sex</p>
# <h4>Styling countplots and barplots</h4>
# <blockquote>
# <ul>
# <li>pallette</li>
# <li>edgecolor</li>
# </ul>
# </blockquote>

# %% [markdown]
# <h3>Race and sex</h3>

# %%
fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(15,5))
sns.countplot(x='race',hue='sex',data=df,palette='afmhot_r')

# %% [markdown]
# <h3>Workclass</h3>

# %%
fig,ax=plt.subplots(nrows=2,ncols=1,figsize=(15,10))
sns.countplot(x='race',hue='workclass',hue_order=df['workclass'].value_counts().reset_index()['index'].tolist(),
data=df,ax=ax[0],palette='Set3_r') #2 categorical columns

sns.countplot(x='sex',hue='workclass',hue_order=df['workclass'].value_counts().reset_index()['index'].tolist(),
data=df,ax=ax[1],palette='Set3_r') #2 categorical columns
#it would be better if the 'workclass' categories could within each race/gender were ordered, for this we need to crosstab

# %% [markdown]
# <h3>Income</h3>

# %%
fig,ax=plt.subplots(nrows=2,ncols=1,figsize=(15,10))
sns.countplot(x='race',hue='income',data=df,ax=ax[0]) #2 categorical columns
sns.countplot(x='sex',hue='income',data=df,ax=ax[1],) #2 categorical columns

# %%
#goal: facetgrid(of swarmplots) of race, sex and income
g=sns.FacetGrid(data=df, col='race',row='sex',hue='income',size=8) #the FacetGrid defintion includes the row and col
g.map(sns.countplot,'education').add_legend()#while .map includes the actual x and y of the spine

# %%
#goal: facetgrid(of swarmplots) of race, sex and income
g=sns.FacetGrid(data=df, col='race',row='sex',hue='income',size=9) #the FacetGrid defintion includes the row and col
g.map(sns.countplot,'occupation').add_legend()#while .map includes the actual x and y of the spine

# %%
facet = sns.FacetGrid(df, hue="income",size=8,aspect=3)
facet.map(sns.kdeplot,'age',shade=True)
facet.set(xlim=(df['age'].min()-5, df['age'].max()))
facet.add_legend()

# %%
facet = sns.FacetGrid(df, hue="income",size=8,aspect=3)
facet.map(sns.kdeplot,'education.num',shade=True)
facet.set(xlim=(df['education.num'].min()-5, df['education.num'].max()))
facet.add_legend()

# %%
fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(15,5))
sns.kdeplot(df['hours.per.week'])

# %%
facet = sns.FacetGrid(df, hue="income",size=8,aspect=3)
facet.map(sns.kdeplot,'hours.per.week',shade=True)
facet.set(xlim=(df['hours.per.week'].min()-5, df['hours.per.week'].max()))
facet.add_legend()

# %%
fig,ax=plt.subplots(nrows=2,ncols=1,figsize=(15,20))
sns.countplot(x='workclass',hue='income',data=df,ax=ax[0]) #2 categorical columns
sns.countplot(y='occupation',hue='income',data=df,ax=ax[1]) #2 categorical columns

# %%
#goal: factor plot of those making >=50k by race and gender breakdown (+ hours/week)
sns.factorplot('income','hours.per.week', hue='sex',col='race',data=df,size=8) #hue determines the number of lines on the plot

# %%
#goal: factor plot of those making >=50k by race and gender breakdown (+ age)
sns.factorplot('income','age', hue='sex',col='race',data=df,size=8)

# %%
sns.factorplot('income','education.num', hue='sex',col='race',data=df,size=8)

# %%
#goal: swarmplot of (education.num) and income. #capital.gain won't work well since there are 119 distinct values

# %%
#goal: FacetGrid of correlation between hours.per.week and income

# %% [markdown]
# <h3>Native Country</h3>

# %%
fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(8,20)) #seaborn can deermine the orientation of the dataset (h or v) based on whether x or y is categorical
sns.barplot(y='native.country', x='fnlwgt',data=df,
palette='RdYlGn_r',edgecolor=sns.color_palette('dark',7))

# %%
fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(8,20)) 
sns.barplot(x='hours.per.week', y='native.country',
data=df.loc[:,['native.country','hours.per.week']].groupby('native.country').sum().reset_index().sort_values(by='hours.per.week',ascending=False),
palette='RdYlGn_r',edgecolor=sns.color_palette('dark',7))

# %%
#conHors['hours.per.week'] displays nothing, unless .sum, .mean, .max is tagged which then returns a Series ob
#notice the columns when you conHors.head()
conHors['hours.per.week'].sum().sort_values(ascending=False)
# Out:
# native.country
# United-States                 1179861
# Mexico                          25939
# ?                               24202
# Philippines                      7840
# Germany                          5619
# Canada                           4889
# Puerto-Rico                      4397
# India                            4153
# El-Salvador                      3900
# England                          3765
# Cuba                             3720
# South                            3393
# Jamaica                          3126
# Italy                            3037
# Dominican-Republic               2973
# China                            2834
# Japan                            2709
# Guatemala                        2511
# Vietnam                          2502
# Columbia                         2305
# Poland                           2300
# Taiwan                           1983
# Iran                             1891
# Haiti                            1624
# ...

# %% [markdown]
# <h3>Heat-map</h3>

# %%
df.drop('fnlwgt',axis=1).corr()
# Out:
#                      age  education.num  capital.gain  capital.loss  \
# age             1.000000       0.036527      0.077674      0.057775
# education.num   0.036527       1.000000      0.122630      0.079923
# capital.gain    0.077674       0.122630      1.000000     -0.031615
# capital.loss    0.057775       0.079923     -0.031615      1.000000
# hours.per.week  0.068756       0.148123      0.078409      0.054256
#
#                 hours.per.week
# age                   0.068756
# education.num         0.148123
# capital.gain          0.078409
# capital.loss          0.054256
# hours.per.week        1.000000

# %%
# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5},annot=True)

# %% [markdown]
# <h3>Scatter plots</h3>
# <p>In order to make a scatter plot of such a large dataset, we'll need to take samples</p>

# %%
fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(15,5))
sns.regplot(x='education.num',y='hours.per.week',data=df.sample(1000))

# %%
sns.lmplot(x='age',y='hours.per.week',data=df.sample(1000),hue='sex',row='income',col='race') #double click on the plot to zoom

# %% [markdown]
# <h2>Relationship</h2>

# %%
fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(8,8))
sns.countplot(y='relationship',hue='income',data=df) #2 categorical columns

# %% [markdown]
# <h2>Marital Status</h2>

# %%
fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(8,8))
sns.countplot(y='marital.status',hue='income',data=df) #2 categorical columns

# %% [markdown]
# <h2>Education Num</h2>

# %%
fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,10))
sns.countplot(y='education',hue='income',data=df) #2 categorical columns

# %% [markdown]
# <h3>Features Engineering</h3>
# <ul>
# <li>Bin Ages</li>
# <li>Binarize Sex</li>
# <li>Drop Education Column</li>
# <li>Binarize Workclass</li>
# <li>Classify Sparse occupations as other then Binarize column</li>
# <li>Relationship:</li>
# </ul>
